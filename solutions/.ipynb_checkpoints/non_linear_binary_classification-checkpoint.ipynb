# %% [markdown]
# # Non-Linear Binary Classification

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from IPython import display

# %%
# prepare data
from data import get_2bubbles, get_2bubbles_oblate, get_2bubbles_prolate, get_4bubbles, get_circles

num_data = 500

x_data, y_target = get_circles(num_data)

plt.set_cmap(plt.cm.bwr)
plt.scatter(x_data[:,0], x_data[:,1], c=y_target.ravel())
plt.show()

# %%
n_features = x_data.shape[1]
n_class = y_target.shape[1]

print("number of features =", n_features)
print("number of classes  =", n_class)
# Out:
# number of features = 2
# number of classes  = 1

# %%
# parameters
learning_rate   = 0.3
training_epochs = 10000
err_threshold   = 1.e-6

n_neurons       = 20

# %%
# placeholder
X = tf.placeholder(tf.float32, shape=(None, n_features), name="x")
Y = tf.placeholder(tf.float32, shape=(None, n_class), name="y")

# create variables for Neural Network layers
# layer 1: inputs -> hidden layer
w1 = tf.Variable(tf.random_normal(shape=[n_features, n_neurons]))
b1 = tf.Variable(tf.random_normal(shape=[n_neurons]))
# layer output: hidden layer -> outputs
w2 = tf.Variable(tf.random_normal(shape=[n_neurons, n_class]))
b2 = tf.Variable(tf.random_normal(shape=[n_class]))

# operations
y1_model = tf.sigmoid(tf.add(tf.matmul(X, w1), b1))
y2_model = tf.sigmoid(tf.add(tf.matmul(y1_model, w2), b2))

# cost Function
loss = tf.reduce_mean( - tf.log(y2_model) * Y - tf.log(1 - y2_model) * (1 - Y))

# optimizer
optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss)

# %%
def plot_decision_boundary():
    plt.figure(figsize=(15, 10))
    # plot decision boundary
    plt.subplot(221)
    xv, yv = np.meshgrid(linsp, linsp)
    zv = y_predict.reshape(xv.shape)
    ics = plt.contourf(xv, yv, zv, zdir='z', offset=0, alpha=0.5)
    #plt.colorbar(ics)
    plt.scatter(x_data[:,0], x_data[:,1], c=y_target.ravel())
    # plot error
    plt.subplot(222)
    plt.plot([x for x in range(epoch+1)], loss_values)
    plt.xlabel("Epoch")
    plt.ylabel("loss function value")
    plt.show()
    
# to plot
off = 0.2
linsp = np.linspace(-1-off, 1+off)
x_predict = np.asarray([np.array([i, j]) for i in linsp for j in linsp])

loss_values = []

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())

    # Training
    prev_err = 0
    for epoch in range(training_epochs):
        err, _ = sess.run([loss, optimizer], {X: x_data, Y: y_target})

        loss_values.append(err)

        if epoch % 100 == 0:
            # Prediction
            y_predict = sess.run(y2_model, {X: x_predict})
            display.clear_output(wait=True)
            print("Epoch = {:2d} - error = {:9.6f}, diff = {:e}".format(epoch, err, abs(err - prev_err)))
            plot_decision_boundary()

        if abs(prev_err - err) < err_threshold:
            print("Exit: diff = {:e}".format(abs(err - prev_err)))
            break

        prev_err = err

    # Prediction
    y_predict = sess.run(y2_model, {X: x_predict})
# Out:
# Epoch = 8600 - error =  0.006963, diff = 1.003034e-06
# Exit: diff = 9.988435e-07
